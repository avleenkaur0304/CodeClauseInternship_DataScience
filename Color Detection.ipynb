# %%
import cv2
import numpy as np
import pandas as pd

# %%
image_path = "colorpic.jpg"
image = cv2.imread(image_path)

# %%
import pandas as pd

# Define column names
index = ['color', 'color_name', 'hex', 'R', 'G', 'B']

# Specify the full path to the CSV file
file_path = r'C:\Users\avkka\Downloads\python-project-color-detection\colors.csv'

# Read the CSV file into a DataFrame
df = pd.read_csv(file_path, names=index, header=None)

# Display the first few rows of the DataFrame
df.head()
# Out:
#                   color             color_name      hex    R    G    B
# 0    air_force_blue_raf   Air Force Blue (Raf)  #5d8aa8   93  138  168
# 1   air_force_blue_usaf  Air Force Blue (Usaf)  #00308f    0   48  143
# 2  air_superiority_blue   Air Superiority Blue  #72a0c1  114  160  193
# 3       alabama_crimson        Alabama Crimson  #a32638  163   38   56
# 4            alice_blue             Alice Blue  #f0f8ff  240  248  255

# %%
clicked = False
r=g=b=xpos=ypos=0

# %%
#Function to get the most matching color with the help of R,G,B values
def getColorName(R,G,B):
    minimum = 10000
    for i in range(len(df)):
        d = abs(R - int(df.loc[i, "R"])) + abs(G - int(df.loc[i, "G"])) + abs(B - int(df.loc[i, "B"]))
        if (d<=minimum):
            minimum = d
            cname = df.loc[i, "color_name"]
    return cname

# %%
#Function to get x,y co-ordinates of mouse double click
import cv2
def draw_function(event, x,y,flags,param):
    if event == cv2.EVENT_LBUTTONDBLCLK:
        global r,g,b,clicked,xpos,ypos
        clicked = True
        xpos = x
        ypos = y
        b,g,r = image[y,x]
        b = int(b)
        g = int(g)
        r = int(r)

# %%
cv2.namedWindow("image")
cv2.setMouseCallback('image', draw_function)

# %%
import cv2

# Function to get color name based on RGB values (you can define your own color mapping logic)
def getColorName(r, g, b):
    # Add your logic here to map RGB values to color names
    # For example, you can use a dictionary or some other method
    # to match RGB values to color names.
    # Replace the following with your logic:
    color_names = {
        (255, 0, 0): 'Red',
        (0, 255, 0): 'Green',
        (0, 0, 255): 'Blue',
        # Add more color mappings as needed
    }
    
    # Check if the RGB values are in the dictionary
    if (r, g, b) in color_names:
        return color_names[(r, g, b)]
    else:
        return 'Unknown'

# Mouse callback function to capture double-click event
def draw_function(event, x, y, flags, param):
    if event == cv2.EVENT_LBUTTONDBLCLK:
        global r, g, b, clicked, xpos, ypos
        clicked = True
        xpos = x
        ypos = y
        b, g, r = image[y, x]
        b = int(b)
        g = int(g)
        r = int(r)

# Load the image
image = cv2.imread("C:\\Users\\avkka\\Downloads\\python-project-color-detection\\colorpic.jpg")

# Create an OpenCV window and set the mouse callback
cv2.namedWindow("image")
cv2.setMouseCallback('image', draw_function)

# Initialize variables
clicked = False
xpos, ypos = -1, -1
r, g, b = 0, 0, 0

# Main loop to display the image and color information
while True:
    cv2.imshow("image", image)
    if clicked:
        # Draw a colored rectangle and display color information
        cv2.rectangle(image, (20, 20), (750, 60), (b, g, r), -1)
        text = getColorName(r, g, b) + ' R=' + str(r) + ' G=' + str(g) + ' B=' + str(b)
        cv2.putText(image, text, (50, 50), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (255, 255, 255), 2, cv2.LINE_AA)
        if r + g + b >= 600:
            cv2.putText(image, text, (50, 50), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 0, 0), 2, cv2.LINE_AA)
        clicked = False

    # Break the loop when the 'Esc' key is pressed
    key = cv2.waitKey(20) & 0xFF
    if key == 27:
        break

# Close all OpenCV windows
cv2.destroyAllWindows
